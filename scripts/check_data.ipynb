# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.load('G:/ZJU/Thesis/codes/data/dog_fish/dataset_dog-fish_train-900_test-300.npz')
v = np.load('G:/ZJU/Thesis/codes/data/car_airplane/dataset_car-airplane_train-1000_test-300.npz')

# %%
img = a['X_train'][600]

# %%
img = v['X_train'][600]

# %%
img2 = ((img+1)*255/2).astype(int)
img2
# Out:
# array([[[ 48,  68,  83],
#         [ 49,  69,  84],
#         [ 51,  70,  87],
#         ...,
#         [111, 125, 134],
#         [ 98, 115, 123],
#         [ 84, 106, 119]],
#
#        [[ 48,  68,  83],
#         [ 49,  69,  84],
#         [ 49,  69,  86],
#         ...,
#         [120, 131, 137],
#         [108, 122, 131],
#         [ 93, 111, 125]],
#
#        [[ 48,  68,  85],
#         [ 48,  68,  85],
#         [ 48,  68,  85],
#         ...,
#         [146, 150, 151],
#         [133, 138, 144],
#         [125, 134, 143]],
#
#        ...,
#
#        [[ 71,  77,  67],
#         [ 64,  71,  38],
#         [ 67,  72,  41],
#         ...,
#         [105, 116, 118],
#         [103, 117, 118],
#         [102, 116, 117]],
#
#        [[ 70,  77,  46],
#         [ 59,  66,  24],
#         [ 56,  62,  24],
#         ...,
#         [103, 117, 118],
#         [103, 117, 117],
#         [103, 117, 117]],
#
#        [[ 48,  56,  24],
#         [ 56,  62,  30],
#         [ 56,  62,  25],
# ...

# %%
plt.imshow(img2)
plt.show()
